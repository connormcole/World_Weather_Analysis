# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add to the cities list
    if city not in cities:
        cities.append(city)

# %%
# Build base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        # Description
        city_descrip = city_weather['weather'][0]['description']
        # Append the city information into city_data list
        city_data.append({'City': city.title(),
                          'Country': city_country,
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Current Description': city_descrip})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | kenai
# Processing Record 11 of Set 1 | dunedin
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | ajdabiya
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | aykhal
# Processing Record 21 of Set 1 | klaksvik
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | ponferrada
# Processing Record 24 of Set 1 | mezhdurechenskiy
# Processing Record 25 of Set 1 | shiyan
# Processing Record 26 of Set 1 | baboua
# City not found. Skipping...
# Processing Record 27 of Set 1 | northwich
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | turukhansk
# Processing Record 30 of Set 1 | kibala
# Processing Record 31 of Set 1 | zhigansk
# Processing Record 32 of Set 1 | yeniseysk
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | viedma
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | korla
# Processing Record 39 of Set 1 | tuatapere
# Processing Record 40 of Set 1 | severiano melo
# Processing Record 41 of Set 1 | richards bay
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | puerto escondido
# Processing Record 45 of Set 1 | mananara
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | katsuura
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | chicama
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | kyren
# Processing Record 5 of Set 2 | narva-joesuu
# Processing Record 6 of Set 2 | bathsheba
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | boyolangu
# Processing Record 9 of Set 2 | guangyuan
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | pacific grove
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | aquiraz
# Processing Record 17 of Set 2 | mayahi
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | quba
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 2 | amberley
# Processing Record 24 of Set 2 | okhotsk
# Processing Record 25 of Set 2 | tatarsk
# Processing Record 26 of Set 2 | roald
# Processing Record 27 of Set 2 | sao joao da barra
# Processing Record 28 of Set 2 | marsh harbour
# Processing Record 29 of Set 2 | ixtapa
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | aasiaat
# Processing Record 32 of Set 2 | pitanga
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | krasnoselkup
# Processing Record 35 of Set 2 | tomatlan
# Processing Record 36 of Set 2 | yamada
# Processing Record 37 of Set 2 | flinders
# Processing Record 38 of Set 2 | lagoa
# Processing Record 39 of Set 2 | el sauce
# Processing Record 40 of Set 2 | gao
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | mantamados
# Processing Record 44 of Set 2 | nago
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | gigmoto
# Processing Record 48 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 2 | vulcan
# Processing Record 50 of Set 2 | itoman
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | half moon bay
# Processing Record 3 of Set 3 | asmar
# Processing Record 4 of Set 3 | weligama
# Processing Record 5 of Set 3 | hudiksvall
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | carutapera
# Processing Record 8 of Set 3 | simao
# Processing Record 9 of Set 3 | matay
# Processing Record 10 of Set 3 | gat
# Processing Record 11 of Set 3 | albany
# Processing Record 12 of Set 3 | shenjiamen
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | komsomolskiy
# Processing Record 15 of Set 3 | thessalon
# Processing Record 16 of Set 3 | san pedro
# Processing Record 17 of Set 3 | westport
# Processing Record 18 of Set 3 | craig
# Processing Record 19 of Set 3 | buala
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | ostrovnoy
# Processing Record 22 of Set 3 | port moresby
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | vardo
# Processing Record 25 of Set 3 | touros
# Processing Record 26 of Set 3 | coquimbo
# Processing Record 27 of Set 3 | krasnaya gorka
# Processing Record 28 of Set 3 | north platte
# Processing Record 29 of Set 3 | eureka
# Processing Record 30 of Set 3 | dakar
# Processing Record 31 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | hobart
# Processing Record 34 of Set 3 | yerofey pavlovich
# Processing Record 35 of Set 3 | kungurtug
# Processing Record 36 of Set 3 | lahij
# Processing Record 37 of Set 3 | cabo san lucas
# Processing Record 38 of Set 3 | lodja
# Processing Record 39 of Set 3 | broome
# Processing Record 40 of Set 3 | dubai
# Processing Record 41 of Set 3 | jiangyou
# Processing Record 42 of Set 3 | vestmannaeyjar
# Processing Record 43 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 3 | cayenne
# Processing Record 45 of Set 3 | pacov
# Processing Record 46 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 3 | baheri
# Processing Record 48 of Set 3 | rio grande
# Processing Record 49 of Set 3 | lasa
# Processing Record 50 of Set 3 | otavi
# Processing Record 1 of Set 4 | onega
# Processing Record 2 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 4 | tasiilaq
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | rawson
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 4 | gidam
# Processing Record 11 of Set 4 | kasempa
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | port-cartier
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | husavik
# Processing Record 16 of Set 4 | santa rosa
# Processing Record 17 of Set 4 | lyngseidet
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | angoche
# Processing Record 20 of Set 4 | moerai
# Processing Record 21 of Set 4 | tessalit
# Processing Record 22 of Set 4 | camocim
# Processing Record 23 of Set 4 | dawei
# Processing Record 24 of Set 4 | eslov
# Processing Record 25 of Set 4 | berlevag
# Processing Record 26 of Set 4 | egvekinot
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | sola
# Processing Record 30 of Set 4 | havre-saint-pierre
# Processing Record 31 of Set 4 | clyde river
# Processing Record 32 of Set 4 | la ronge
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | sterling
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | bogatoye
# Processing Record 37 of Set 4 | margate
# Processing Record 38 of Set 4 | parfenyevo
# Processing Record 39 of Set 4 | asfi
# Processing Record 40 of Set 4 | aksha
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | mogapinyana
# Processing Record 43 of Set 4 | coahuayana
# Processing Record 44 of Set 4 | sun city west
# Processing Record 45 of Set 4 | faya
# Processing Record 46 of Set 4 | faanui
# Processing Record 47 of Set 4 | qaqortoq
# Processing Record 48 of Set 4 | atascadero
# Processing Record 49 of Set 4 | sunndalsora
# Processing Record 50 of Set 4 | tautira
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | san vicente
# Processing Record 3 of Set 5 | tukums
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | andenes
# Processing Record 6 of Set 5 | jagatsinghapur
# Processing Record 7 of Set 5 | kapaa
# Processing Record 8 of Set 5 | alice springs
# Processing Record 9 of Set 5 | ostersund
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | jumla
# Processing Record 12 of Set 5 | grand-santi
# Processing Record 13 of Set 5 | constitucion
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | deputatskiy
# Processing Record 16 of Set 5 | thio
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | grand gaube
# Processing Record 19 of Set 5 | galle
# Processing Record 20 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 5 | dalbandin
# Processing Record 22 of Set 5 | cam ranh
# Processing Record 23 of Set 5 | vila velha
# Processing Record 24 of Set 5 | gravdal
# Processing Record 25 of Set 5 | fort nelson
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | neuquen
# Processing Record 28 of Set 5 | meulaboh
# Processing Record 29 of Set 5 | avera
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | saldanha
# Processing Record 32 of Set 5 | paamiut
# Processing Record 33 of Set 5 | mayo
# Processing Record 34 of Set 5 | shieli
# Processing Record 35 of Set 5 | praia
# Processing Record 36 of Set 5 | khatanga
# Processing Record 37 of Set 5 | salamanca
# Processing Record 38 of Set 5 | stupino
# Processing Record 39 of Set 5 | kyra
# Processing Record 40 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 5 | gorontalo
# Processing Record 42 of Set 5 | abu samrah
# Processing Record 43 of Set 5 | pangnirtung
# Processing Record 44 of Set 5 | bitung
# Processing Record 45 of Set 5 | tateyama
# Processing Record 46 of Set 5 | katav-ivanovsk
# Processing Record 47 of Set 5 | ivnya
# Processing Record 48 of Set 5 | axim
# Processing Record 49 of Set 5 | banda aceh
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | sydney
# Processing Record 2 of Set 6 | msanga
# Processing Record 3 of Set 6 | nikolskoye
# Processing Record 4 of Set 6 | abu dhabi
# Processing Record 5 of Set 6 | umrala
# Processing Record 6 of Set 6 | hayesville
# Processing Record 7 of Set 6 | azangaro
# Processing Record 8 of Set 6 | issoudun
# Processing Record 9 of Set 6 | tyup
# Processing Record 10 of Set 6 | shibarghan
# City not found. Skipping...
# Processing Record 11 of Set 6 | tres arroyos
# Processing Record 12 of Set 6 | kisangani
# Processing Record 13 of Set 6 | yulara
# Processing Record 14 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 6 | bud
# Processing Record 16 of Set 6 | yeppoon
# Processing Record 17 of Set 6 | cuenca
# Processing Record 18 of Set 6 | beruwala
# Processing Record 19 of Set 6 | aksu
# Processing Record 20 of Set 6 | lebu
# Processing Record 21 of Set 6 | vila franca do campo
# Processing Record 22 of Set 6 | labuhan
# Processing Record 23 of Set 6 | leshukonskoye
# Processing Record 24 of Set 6 | te anau
# Processing Record 25 of Set 6 | kudahuvadhoo
# Processing Record 26 of Set 6 | coos bay
# Processing Record 27 of Set 6 | sao felix do xingu
# Processing Record 28 of Set 6 | airai
# Processing Record 29 of Set 6 | sambava
# Processing Record 30 of Set 6 | taltal
# Processing Record 31 of Set 6 | manggar
# Processing Record 32 of Set 6 | yerbogachen
# Processing Record 33 of Set 6 | pochinok
# Processing Record 34 of Set 6 | bahile
# Processing Record 35 of Set 6 | khingansk
# Processing Record 36 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 37 of Set 6 | kamaishi
# Processing Record 38 of Set 6 | dong hoi
# Processing Record 39 of Set 6 | trois-rivieres
# Processing Record 40 of Set 6 | camacupa
# Processing Record 41 of Set 6 | uige
# Processing Record 42 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 6 | jalu
# Processing Record 44 of Set 6 | bjorkelangen
# Processing Record 45 of Set 6 | tiksi
# Processing Record 46 of Set 6 | laguna
# Processing Record 47 of Set 6 | vostok
# Processing Record 48 of Set 6 | mecca
# Processing Record 49 of Set 6 | belaya gora
# Processing Record 50 of Set 6 | flin flon
# Processing Record 1 of Set 7 | ambon
# Processing Record 2 of Set 7 | horki
# Processing Record 3 of Set 7 | caapucu
# Processing Record 4 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 7 | birao
# Processing Record 6 of Set 7 | victoria
# Processing Record 7 of Set 7 | kununurra
# Processing Record 8 of Set 7 | minatitlan
# Processing Record 9 of Set 7 | manaure
# Processing Record 10 of Set 7 | saint-joseph
# Processing Record 11 of Set 7 | udachnyy
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | gold coast
# Processing Record 14 of Set 7 | port hardy
# Processing Record 15 of Set 7 | hobyo
# Processing Record 16 of Set 7 | kutum
# Processing Record 17 of Set 7 | visnes
# Processing Record 18 of Set 7 | homer
# Processing Record 19 of Set 7 | high level
# Processing Record 20 of Set 7 | gizo
# Processing Record 21 of Set 7 | camacha
# Processing Record 22 of Set 7 | roi et
# Processing Record 23 of Set 7 | chokurdakh
# Processing Record 24 of Set 7 | pisco
# Processing Record 25 of Set 7 | loukhi
# Processing Record 26 of Set 7 | sitka
# Processing Record 27 of Set 7 | svetlaya
# Processing Record 28 of Set 7 | otradnoye
# Processing Record 29 of Set 7 | drayton valley
# Processing Record 30 of Set 7 | kurilsk
# Processing Record 31 of Set 7 | grindavik
# Processing Record 32 of Set 7 | liwale
# Processing Record 33 of Set 7 | verkhoyansk
# Processing Record 34 of Set 7 | oktyabrskoye
# Processing Record 35 of Set 7 | mbaiki
# Processing Record 36 of Set 7 | henties bay
# Processing Record 37 of Set 7 | topchikha
# Processing Record 38 of Set 7 | borgarnes
# Processing Record 39 of Set 7 | sao lourenco do sul
# Processing Record 40 of Set 7 | labytnangi
# Processing Record 41 of Set 7 | dunmore east
# Processing Record 42 of Set 7 | honiara
# Processing Record 43 of Set 7 | mandera
# Processing Record 44 of Set 7 | itarema
# Processing Record 45 of Set 7 | ancud
# Processing Record 46 of Set 7 | tezu
# Processing Record 47 of Set 7 | funadhoo
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | bidor
# Processing Record 50 of Set 7 | codrington
# Processing Record 1 of Set 8 | mangan
# Processing Record 2 of Set 8 | fairbanks
# Processing Record 3 of Set 8 | opmeer
# Processing Record 4 of Set 8 | pemberton
# Processing Record 5 of Set 8 | hualmay
# Processing Record 6 of Set 8 | road town
# Processing Record 7 of Set 8 | shingu
# Processing Record 8 of Set 8 | esperance
# Processing Record 9 of Set 8 | rebrikha
# Processing Record 10 of Set 8 | kanturk
# Processing Record 11 of Set 8 | san-pedro
# Processing Record 12 of Set 8 | dongying
# Processing Record 13 of Set 8 | elat
# Processing Record 14 of Set 8 | agadez
# Processing Record 15 of Set 8 | cidreira
# Processing Record 16 of Set 8 | bethel
# Processing Record 17 of Set 8 | caucaia
# Processing Record 18 of Set 8 | kerman
# Processing Record 19 of Set 8 | brae
# Processing Record 20 of Set 8 | atasu
# Processing Record 21 of Set 8 | lompoc
# Processing Record 22 of Set 8 | la maddalena
# Processing Record 23 of Set 8 | pawa
# Processing Record 24 of Set 8 | lumut
# Processing Record 25 of Set 8 | nizwa
# Processing Record 26 of Set 8 | arrifes
# Processing Record 27 of Set 8 | saint-augustin
# Processing Record 28 of Set 8 | padang
# Processing Record 29 of Set 8 | san patricio
# Processing Record 30 of Set 8 | kayerkan
# Processing Record 31 of Set 8 | mananjary
# Processing Record 32 of Set 8 | norman wells
# Processing Record 33 of Set 8 | vanavara
# Processing Record 34 of Set 8 | salalah
# Processing Record 35 of Set 8 | pedasi
# Processing Record 36 of Set 8 | sorumsand
# Processing Record 37 of Set 8 | vredendal
# Processing Record 38 of Set 8 | nome
# Processing Record 39 of Set 8 | kavaratti
# Processing Record 40 of Set 8 | svetlyy
# Processing Record 41 of Set 8 | buin
# Processing Record 42 of Set 8 | vavoua
# Processing Record 43 of Set 8 | eston
# Processing Record 44 of Set 8 | dezful
# Processing Record 45 of Set 8 | bohl-iggelheim
# Processing Record 46 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 47 of Set 8 | bilma
# Processing Record 48 of Set 8 | aubergenville
# Processing Record 49 of Set 8 | maple creek
# Processing Record 50 of Set 8 | kruisfontein
# Processing Record 1 of Set 9 | chacabuco
# Processing Record 2 of Set 9 | lincoln
# Processing Record 3 of Set 9 | muroto
# Processing Record 4 of Set 9 | boende
# Processing Record 5 of Set 9 | vasto
# Processing Record 6 of Set 9 | kiama
# Processing Record 7 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 9 | el alto
# Processing Record 9 of Set 9 | shahrud
# Processing Record 10 of Set 9 | altamira
# Processing Record 11 of Set 9 | mandalgovi
# Processing Record 12 of Set 9 | kaitangata
# Processing Record 13 of Set 9 | ahipara
# Processing Record 14 of Set 9 | turki
# Processing Record 15 of Set 9 | sorong
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | narsaq
# Processing Record 18 of Set 9 | west odessa
# Processing Record 19 of Set 9 | najran
# Processing Record 20 of Set 9 | jutai
# Processing Record 21 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 9 | bilibino
# Processing Record 23 of Set 9 | olonets
# Processing Record 24 of Set 9 | adrasmon
# Processing Record 25 of Set 9 | wamba
# Processing Record 26 of Set 9 | hangu
# Processing Record 27 of Set 9 | almaznyy
# Processing Record 28 of Set 9 | yiyang
# Processing Record 29 of Set 9 | charcas
# Processing Record 30 of Set 9 | praia da vitoria
# Processing Record 31 of Set 9 | shimoda
# Processing Record 32 of Set 9 | abu kamal
# Processing Record 33 of Set 9 | naryan-mar
# Processing Record 34 of Set 9 | kirakira
# Processing Record 35 of Set 9 | san rafael
# Processing Record 36 of Set 9 | xuanzhou
# Processing Record 37 of Set 9 | riga
# Processing Record 38 of Set 9 | tuy hoa
# Processing Record 39 of Set 9 | acarau
# Processing Record 40 of Set 9 | ucluelet
# Processing Record 41 of Set 9 | butwal
# Processing Record 42 of Set 9 | awjilah
# Processing Record 43 of Set 9 | mesquite
# Processing Record 44 of Set 9 | palu
# Processing Record 45 of Set 9 | luena
# Processing Record 46 of Set 9 | champerico
# Processing Record 47 of Set 9 | malibu
# Processing Record 48 of Set 9 | fethiye
# Processing Record 49 of Set 9 | farah
# Processing Record 50 of Set 9 | wampusirpi
# City not found. Skipping...
# Processing Record 1 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 10 | zhangye
# Processing Record 3 of Set 10 | kiambu
# Processing Record 4 of Set 10 | port blair
# Processing Record 5 of Set 10 | porbandar
# Processing Record 6 of Set 10 | aljezur
# Processing Record 7 of Set 10 | nanortalik
# Processing Record 8 of Set 10 | warangal
# Processing Record 9 of Set 10 | lermontovka
# Processing Record 10 of Set 10 | bodmin
# Processing Record 11 of Set 10 | two hills
# Processing Record 12 of Set 10 | makakilo city
# Processing Record 13 of Set 10 | jubb jannin
# City not found. Skipping...
# Processing Record 14 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 15 of Set 10 | umm kaddadah
# Processing Record 16 of Set 10 | novyy urengoy
# Processing Record 17 of Set 10 | ikauna
# Processing Record 18 of Set 10 | murud
# Processing Record 19 of Set 10 | quatre cocos
# Processing Record 20 of Set 10 | san carlos de bariloche
# Processing Record 21 of Set 10 | redmond
# Processing Record 22 of Set 10 | cody
# Processing Record 23 of Set 10 | evanston
# Processing Record 24 of Set 10 | bobonong
# City not found. Skipping...
# Processing Record 25 of Set 10 | bandarbeyla
# Processing Record 26 of Set 10 | stribro
# Processing Record 27 of Set 10 | sarangani
# Processing Record 28 of Set 10 | novokayakent
# Processing Record 29 of Set 10 | nalut
# Processing Record 30 of Set 10 | kinablangan
# Processing Record 31 of Set 10 | namibe
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | bandundu
# Processing Record 34 of Set 10 | otjimbingwe
# Processing Record 35 of Set 10 | voh
# Processing Record 36 of Set 10 | dawson creek
# Processing Record 37 of Set 10 | cabra
# Processing Record 38 of Set 10 | nurota
# Processing Record 39 of Set 10 | kampot
# Processing Record 40 of Set 10 | monroe
# Processing Record 41 of Set 10 | gazojak
# Processing Record 42 of Set 10 | jaguarao
# Processing Record 43 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 10 | hasaki
# Processing Record 45 of Set 10 | gorele
# Processing Record 46 of Set 10 | saurimo
# Processing Record 47 of Set 10 | cururupu
# Processing Record 48 of Set 10 | nara
# Processing Record 49 of Set 10 | kushima
# Processing Record 50 of Set 10 | laranjeiras do sul
# Processing Record 1 of Set 11 | cascais
# Processing Record 2 of Set 11 | collie
# Processing Record 3 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 11 | borogontsy
# Processing Record 5 of Set 11 | the pas
# Processing Record 6 of Set 11 | sangueya
# Processing Record 7 of Set 11 | krasnoarmeysk
# Processing Record 8 of Set 11 | lauro muller
# Processing Record 9 of Set 11 | encinitas
# Processing Record 10 of Set 11 | mount gambier
# Processing Record 11 of Set 11 | kangalassy
# Processing Record 12 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 13 of Set 11 | tabou
# Processing Record 14 of Set 11 | maceio
# Processing Record 15 of Set 11 | shelburne
# Processing Record 16 of Set 11 | nicoya
# Processing Record 17 of Set 11 | barcelos
# Processing Record 18 of Set 11 | bajil
# Processing Record 19 of Set 11 | conceicao da barra
# Processing Record 20 of Set 11 | guerrero negro
# Processing Record 21 of Set 11 | atambua
# Processing Record 22 of Set 11 | bontang
# Processing Record 23 of Set 11 | kleck
# City not found. Skipping...
# Processing Record 24 of Set 11 | pandan niog
# Processing Record 25 of Set 11 | goderich
# Processing Record 26 of Set 11 | paramonga
# Processing Record 27 of Set 11 | aswan
# Processing Record 28 of Set 11 | mirnyy
# Processing Record 29 of Set 11 | fortuna
# Processing Record 30 of Set 11 | puerto madero
# Processing Record 31 of Set 11 | opuwo
# Processing Record 32 of Set 11 | kieta
# Processing Record 33 of Set 11 | lavrentiya
# Processing Record 34 of Set 11 | campbell river
# Processing Record 35 of Set 11 | tubmanburg
# Processing Record 36 of Set 11 | juazeiro
# Processing Record 37 of Set 11 | mehamn
# Processing Record 38 of Set 11 | nyurba
# Processing Record 39 of Set 11 | yuryevets
# Processing Record 40 of Set 11 | calatayud
# Processing Record 41 of Set 11 | george town
# Processing Record 42 of Set 11 | mont-de-marsan
# Processing Record 43 of Set 11 | port-gentil
# Processing Record 44 of Set 11 | beclean
# Processing Record 45 of Set 11 | sur
# Processing Record 46 of Set 11 | alkhan-churt
# Processing Record 47 of Set 11 | presidente epitacio
# Processing Record 48 of Set 11 | namwala
# Processing Record 49 of Set 11 | prince rupert
# Processing Record 50 of Set 11 | kifri
# Processing Record 1 of Set 12 | mahibadhoo
# Processing Record 2 of Set 12 | vaasa
# Processing Record 3 of Set 12 | camopi
# Processing Record 4 of Set 12 | selma
# Processing Record 5 of Set 12 | sioux lookout
# Processing Record 6 of Set 12 | jalgaon
# Processing Record 7 of Set 12 | clearwater
# Processing Record 8 of Set 12 | aketi
# Processing Record 9 of Set 12 | bardiyah
# Processing Record 10 of Set 12 | lazaro cardenas
# Processing Record 11 of Set 12 | cortez
# Processing Record 12 of Set 12 | virginia beach
# Processing Record 13 of Set 12 | mazagao
# Processing Record 14 of Set 12 | amahai
# Processing Record 15 of Set 12 | verkhnevilyuysk
# Processing Record 16 of Set 12 | gari
# Processing Record 17 of Set 12 | baykit
# Processing Record 18 of Set 12 | washougal
# Processing Record 19 of Set 12 | eyl
# Processing Record 20 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 12 | kapustin yar-1
# City not found. Skipping...
# Processing Record 22 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 23 of Set 12 | ambilobe
# Processing Record 24 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 12 | pingliang
# Processing Record 26 of Set 12 | rocha
# Processing Record 27 of Set 12 | aksarka
# Processing Record 28 of Set 12 | yinchuan
# Processing Record 29 of Set 12 | bethanien
# Processing Record 30 of Set 12 | port elizabeth
# Processing Record 31 of Set 12 | wawina
# Processing Record 32 of Set 12 | dire
# Processing Record 33 of Set 12 | saint-francois
# Processing Record 34 of Set 12 | whitianga
# Processing Record 35 of Set 12 | rehau
# Processing Record 36 of Set 12 | monte santo
# Processing Record 37 of Set 12 | pochutla
# Processing Record 38 of Set 12 | kudat
# Processing Record 39 of Set 12 | laredo
# Processing Record 40 of Set 12 | agucadoura
# Processing Record 41 of Set 12 | makinsk
# Processing Record 42 of Set 12 | ketchikan
# Processing Record 43 of Set 12 | tommot
# Processing Record 44 of Set 12 | brazzaville
# Processing Record 45 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 12 | alekseyevsk
# Processing Record 47 of Set 12 | khandyga
# Processing Record 48 of Set 12 | lisala
# Processing Record 49 of Set 12 | chara
# Processing Record 50 of Set 12 | muros
# Processing Record 1 of Set 13 | geraldton
# Processing Record 2 of Set 13 | bahar
# Processing Record 3 of Set 13 | muleba
# Processing Record 4 of Set 13 | portland
# Processing Record 5 of Set 13 | esil
# Processing Record 6 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 13 | gollere
# City not found. Skipping...
# Processing Record 8 of Set 13 | bodden town
# Processing Record 9 of Set 13 | ossora
# Processing Record 10 of Set 13 | zhezkazgan
# Processing Record 11 of Set 13 | jiaohe
# Processing Record 12 of Set 13 | bucerias
# Processing Record 13 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 14 of Set 13 | dasoguz
# Processing Record 15 of Set 13 | takoradi
# Processing Record 16 of Set 13 | pamplona
# Processing Record 17 of Set 13 | srednekolymsk
# Processing Record 18 of Set 13 | north bend
# Processing Record 19 of Set 13 | morlaix
# Processing Record 20 of Set 13 | miri
# Processing Record 21 of Set 13 | sinnamary
# Processing Record 22 of Set 13 | kaeo
# Processing Record 23 of Set 13 | necochea
# Processing Record 24 of Set 13 | suao
# City not found. Skipping...
# Processing Record 25 of Set 13 | neiafu
# Processing Record 26 of Set 13 | mhlambanyatsi
# Processing Record 27 of Set 13 | gornyy
# Processing Record 28 of Set 13 | ust-tsilma
# Processing Record 29 of Set 13 | cap malheureux
# Processing Record 30 of Set 13 | iranshahr
# Processing Record 31 of Set 13 | kalmunai
# Processing Record 32 of Set 13 | thinadhoo
# Processing Record 33 of Set 13 | tambopata
# Processing Record 34 of Set 13 | raudeberg
# Processing Record 35 of Set 13 | anshun
# Processing Record 36 of Set 13 | hovd
# Processing Record 37 of Set 13 | general roca
# Processing Record 38 of Set 13 | vao
# Processing Record 39 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 13 | kouango
# Processing Record 41 of Set 13 | nicolas bravo
# Processing Record 42 of Set 13 | hambantota
# Processing Record 43 of Set 13 | maracas
# Processing Record 44 of Set 13 | xichang
# Processing Record 45 of Set 13 | postrelmov
# Processing Record 46 of Set 13 | kiunga
# Processing Record 47 of Set 13 | cardston
# Processing Record 48 of Set 13 | orange
# Processing Record 49 of Set 13 | maragogi
# Processing Record 50 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 14 | anadyr
# Processing Record 2 of Set 14 | dothan
# Processing Record 3 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 14 | akdepe
# Processing Record 5 of Set 14 | koumac
# Processing Record 6 of Set 14 | olafsvik
# Processing Record 7 of Set 14 | charyshskoye
# Processing Record 8 of Set 14 | saint-georges
# Processing Record 9 of Set 14 | kalaleh
# Processing Record 10 of Set 14 | elkton
# Processing Record 11 of Set 14 | galveston
# Processing Record 12 of Set 14 | solnechnyy
# Processing Record 13 of Set 14 | lively
# Processing Record 14 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 14 | ayan
# Processing Record 16 of Set 14 | miracatu
# Processing Record 17 of Set 14 | bauchi
# Processing Record 18 of Set 14 | gubbi
# Processing Record 19 of Set 14 | debre tabor
# Processing Record 20 of Set 14 | peniche
# Processing Record 21 of Set 14 | sisimiut
# Processing Record 22 of Set 14 | cuamba
# Processing Record 23 of Set 14 | akyab
# Processing Record 24 of Set 14 | serta
# Processing Record 25 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 14 | balkhash
# Processing Record 27 of Set 14 | saint anthony
# Processing Record 28 of Set 14 | riyadh
# Processing Record 29 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 14 | nan
# Processing Record 31 of Set 14 | evensk
# Processing Record 32 of Set 14 | robertsport
# Processing Record 33 of Set 14 | hvolsvollur
# Processing Record 34 of Set 14 | coleraine
# Processing Record 35 of Set 14 | katakwi
# Processing Record 36 of Set 14 | hearst
# Processing Record 37 of Set 14 | zaysan
# Processing Record 38 of Set 14 | chirongui
# Processing Record 39 of Set 14 | jales
# Processing Record 40 of Set 14 | talaya
# Processing Record 41 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 14 | taunggyi
# Processing Record 43 of Set 14 | denpasar
# Processing Record 44 of Set 14 | caramay
# Processing Record 45 of Set 14 | kuala terengganu
# Processing Record 46 of Set 14 | manapla
# Processing Record 47 of Set 14 | stamsund
# City not found. Skipping...
# Processing Record 48 of Set 14 | nemuro
# Processing Record 49 of Set 14 | west bay
# Processing Record 50 of Set 14 | haines junction
# Processing Record 1 of Set 15 | yenagoa
# Processing Record 2 of Set 15 | noumea
# Processing Record 3 of Set 15 | ulaanbaatar
# Processing Record 4 of Set 15 | isla mujeres
# Processing Record 5 of Set 15 | calama
# Processing Record 6 of Set 15 | amapa
# Processing Record 7 of Set 15 | sharhorod
# Processing Record 8 of Set 15 | sabha
# Processing Record 9 of Set 15 | vanimo
# Processing Record 10 of Set 15 | dhidhdhoo
# Processing Record 11 of Set 15 | khartoum
# Processing Record 12 of Set 15 | ivanteyevka
# Processing Record 13 of Set 15 | mayumba
# Processing Record 14 of Set 15 | sorland
# Processing Record 15 of Set 15 | seoul
# Processing Record 16 of Set 15 | mackenzie
# Processing Record 17 of Set 15 | fayaoue
# Processing Record 18 of Set 15 | mysliborz
# Processing Record 19 of Set 15 | gerash
# Processing Record 20 of Set 15 | epe
# Processing Record 21 of Set 15 | qui nhon
# Processing Record 22 of Set 15 | nabire
# Processing Record 23 of Set 15 | alta floresta
# Processing Record 24 of Set 15 | morris
# Processing Record 25 of Set 15 | hirara
# Processing Record 26 of Set 15 | brigantine
# Processing Record 27 of Set 15 | samana
# Processing Record 28 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 15 | tucurui
# Processing Record 30 of Set 15 | itaituba
# Processing Record 31 of Set 15 | ledyard
# Processing Record 32 of Set 15 | rawalpindi
# Processing Record 33 of Set 15 | tshela
# Processing Record 34 of Set 15 | montrose
# Processing Record 35 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 15 | berezanka
# Processing Record 37 of Set 15 | bahia honda
# Processing Record 38 of Set 15 | zongozotla
# Processing Record 39 of Set 15 | presidencia roque saenz pena
# Processing Record 40 of Set 15 | san quintin
# Processing Record 41 of Set 15 | kollumerland
# City not found. Skipping...
# Processing Record 42 of Set 15 | hopewell
# Processing Record 43 of Set 15 | lantawan
# Processing Record 44 of Set 15 | padre paraiso
# Processing Record 45 of Set 15 | vallentuna
# Processing Record 46 of Set 15 | mackay
# Processing Record 47 of Set 15 | etchojoa
# Processing Record 48 of Set 15 | olyka
# Processing Record 49 of Set 15 | mao
# Processing Record 50 of Set 15 | vilhena
# Processing Record 1 of Set 16 | derzhavinsk
# Processing Record 2 of Set 16 | bulungu
# Processing Record 3 of Set 16 | ust-omchug
# Processing Record 4 of Set 16 | lugovskiy
# City not found. Skipping...
# Processing Record 5 of Set 16 | zyryanka
# Processing Record 6 of Set 16 | amurzet
# Processing Record 7 of Set 16 | moyale
# Processing Record 8 of Set 16 | baghdad
# Processing Record 9 of Set 16 | luoyang
# Processing Record 10 of Set 16 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 16 | sistranda
# Processing Record 12 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 16 | sabinas hidalgo
# Processing Record 14 of Set 16 | juneau
# Processing Record 15 of Set 16 | port hedland
# Processing Record 16 of Set 16 | abu zabad
# Processing Record 17 of Set 16 | jawala mukhi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     51.12        50          72
# 1      Hermanus      ZA -34.4187   19.2345     68.81        81         100
# 2       Mataura      NZ -46.1927  168.8643     45.48        99          79
# 3     Mahebourg      MU -20.4081   57.7000     79.09        65          75
# 4         Vaini      TO -21.2000 -175.2000     75.36        94          40
# 5     Upernavik      GL  72.7868  -56.1549      3.31        93         100
# 6       Ushuaia      AR -54.8000  -68.3000     46.06        71          75
# 7   Provideniya      RU  64.3833 -173.3000    -10.17        88          54
# 8         Kenai      US  60.5544 -151.2583    -10.97        80           1
# 9       Dunedin      NZ -45.8742  170.5036     52.81        84          94
#
#    Wind Speed      Current Description
# 0       26.22            broken clouds
# 1        2.73          overcast clouds
# 2        1.83            broken clouds
# 3       11.50            broken clouds
# 4        4.61               light rain
# 5        9.55          overcast clouds
# 6       34.52  light intensity drizzle
# 7        5.48            broken clouds
# 8        0.00                     haze
# 9        4.00          overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
